# %% [markdown]
# <a href="https://colab.research.google.com/github/random-logic/STA106-programming/blob/master/R_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the IRdisplay library
library(IRdisplay)

# Generate a sample of 100 values from a normal distribution
sample <- rnorm(100)

# Plot the sample
plot(sample)

res <- paste("$x_5 = ", round(sample[5], 4), "$", sep="")
display_markdown(res)
# Out:
# $x_5 = -0.0176$
# plot without title

# %% [markdown]
# Sample text box
